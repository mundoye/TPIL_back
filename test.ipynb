# %%
import pandas as pd

# %%
data = pd.read_pickle('./4g_moy7.pkl')
data.head()
# Out:
#          Cellule  moy 7 VolumeDL 2018-01  moy 7 VolumeDL2018-02  \
# 0        ACAD_e1                5.766686               4.683743
# 1        ACAD_e2                5.252057               4.327729
# 2        ACAD_e3                3.175871               3.270286
# 3  ALMADIES02_e1                3.215943               3.335929
# 4  ALMADIES02_e2                0.713614               0.933371
#
#    moy 7 VolumeDL2018-03  moy 7 VolumeDL2018-04  moy 7 VolumeDL2018-05  \
# 0               5.477557               5.925614               2.456371
# 1               3.220629               3.560643               3.607529
# 2               3.648800               4.327829               4.221557
# 3               3.590543               3.999686               3.258671
# 4               0.562829               0.923957               0.381486
#
#    moy 7 VolumeDL2018-06  moy 7 VolumeDL2018-07  moy 7 VolumeDL2018-08  \
# 0               3.047843               3.011643               3.755814
# ...

# %%
avg7 = pd.read_excel("moy7.xlsx")
avg21 = pd.read_excel("moy21.xlsx")
Max = pd.read_excel("max.xlsx")

# %%
avg7.to_pickle("Avg7.pkl")
avg21.to_pickle("Avg21.pkl")
Max.to_pickle("Max.pkl")

# %%
frrr = agv7.columns.to_frame()[0:][1:]
frrr
# Out:
#                                        0
# 2019-01-01 00:00:00  2019-01-01 00:00:00
# 2019-02-01 00:00:00  2019-02-01 00:00:00
# 2019-03-01 00:00:00  2019-03-01 00:00:00
# 2019-04-01 00:00:00  2019-04-01 00:00:00
# 2019-05-01 00:00:00  2019-05-01 00:00:00
# 2019-06-01 00:00:00  2019-06-01 00:00:00
# 2019-07-01 00:00:00  2019-07-01 00:00:00
# 2019-08-01 00:00:00  2019-08-01 00:00:00
# 2019-09-01 00:00:00  2019-09-01 00:00:00
# 2019-10-01 00:00:00  2019-10-01 00:00:00
# 2019-11-01 00:00:00  2019-11-01 00:00:00
# 2019-12-01 00:00:00  2019-12-01 00:00:00
# 2020-01-01 00:00:00  2020-01-01 00:00:00
# 2020-02-01 00:00:00  2020-02-01 00:00:00
# 2020-03-01 00:00:00  2020-03-01 00:00:00
# 2020-04-01 00:00:00  2020-04-01 00:00:00
# 2020-05-01 00:00:00  2020-05-01 00:00:00
# 2020-06-01 00:00:00  2020-06-01 00:00:00
# 2020-07-01 00:00:00  2020-07-01 00:00:00
# 2020-08-01 00:00:00  2020-08-01 00:00:00
# 2020-09-01 00:00:00  2020-09-01 00:00:00
# 2020-10-01 00:00:00  2020-10-01 00:00:00
# ...

# %%
frrr.to_string()
# Out:
# '                                       0\n2019-01-01 00:00:00  2019-01-01 00:00:00\n2019-02-01 00:00:00  2019-02-01 00:00:00\n2019-03-01 00:00:00  2019-03-01 00:00:00\n2019-04-01 00:00:00  2019-04-01 00:00:00\n2019-05-01 00:00:00  2019-05-01 00:00:00\n2019-06-01 00:00:00  2019-06-01 00:00:00\n2019-07-01 00:00:00  2019-07-01 00:00:00\n2019-08-01 00:00:00  2019-08-01 00:00:00\n2019-09-01 00:00:00  2019-09-01 00:00:00\n2019-10-01 00:00:00  2019-10-01 00:00:00\n2019-11-01 00:00:00  2019-11-01 00:00:00\n2019-12-01 00:00:00  2019-12-01 00:00:00\n2020-01-01 00:00:00  2020-01-01 00:00:00\n2020-02-01 00:00:00  2020-02-01 00:00:00\n2020-03-01 00:00:00  2020-03-01 00:00:00\n2020-04-01 00:00:00  2020-04-01 00:00:00\n2020-05-01 00:00:00  2020-05-01 00:00:00\n2020-06-01 00:00:00  2020-06-01 00:00:00\n2020-07-01 00:00:00  2020-07-01 00:00:00\n2020-08-01 00:00:00  2020-08-01 00:00:00\n2020-09-01 00:00:00  2020-09-01 00:00:00\n2020-10-01 00:00:00  2020-10-01 00:00:00\n2020-11-01 00:00:00  2020-11-01
# ...

# %%
agv7.head()
# Out:
#     Cellule 2019-01-01 00:00:00 2019-02-01 00:00:00 2019-03-01 00:00:00  \
# 0  ABENE_e1                 NaN                 NaN                 NaN
# 1  ABENE_e2                 NaN                 NaN                 NaN
# 2  ABENE_e3                 NaN                 NaN                 NaN
# 3   ACAD_e1             3.93487             1.23867            0.930343
# 4  ACAD_e11                 NaN                 NaN                 NaN
#
#   2019-04-01 00:00:00 2019-05-01 00:00:00 2019-06-01 00:00:00  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3             1.13633            0.746186             1.34056
# 4                 NaN                 NaN                 NaN
#
#   2019-07-01 00:00:00 2019-08-01 00:00:00 2019-09-01 00:00:00  ...  \
# 0                 NaN                 NaN                 NaN  ...
# ...
